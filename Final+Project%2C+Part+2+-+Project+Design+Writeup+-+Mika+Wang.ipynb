# %%
### Project Problem and Hypothesis

# What's the project about? What problem are you solving?
## I am looking at rates of recidivism or return to prison 3-years after being released from prison.
## Understanding who returns to prison, when, and why will help law enforcement proactively manage those at high-risk 
### of recidivism, better allocating resources and budgets to do so. In addition, this may help shed a light on what 
### biases may exist for released inmates. 

# Where does this seem to reside as a machine learning problem? Are you predicting some continuous number, or predicting a binary value?
## We are using ML for two parts. One, to predict whether recidivism occurs (based on features including age at release, convicting class classification, convicting offense
### type, release type, etc.) and two, for those who do eventually return to prison, how many days to recividism. 

# What kind of impact do you think it could have?
## As mentioned above, understand who returns to prison, when and why will help not only better allocate resources, 
### but also proactively manage inmates and the biases that may affect officers decisions in repeat sentencing. 

# What do you think will have the most impact in predicting the value you are interested in solving for?
## Convicting Offense Type, Sex (M>F), and Release Type.

# %%
import pandas as pd
import json

data = pd.read_csv("/Users/MikaBook/Downloads/3-Year_Recidivism_for_Offenders_Released_from_Prison.csv", sep=',')

# %%
data.describe()
# Out:
#        Fiscal Year Released  Recidivism Reporting Year  Days to Recidivism
# count          17060.000000               17060.000000         5404.000000
# mean            2011.609496                2014.609496          473.166358
# std                1.105981                   1.105981          283.185134
# min             2010.000000                2013.000000            0.000000
# 25%             2011.000000                2014.000000          241.000000
# 50%             2012.000000                2015.000000          418.000000
# 75%             2013.000000                2016.000000          687.000000
# max             2013.000000                2016.000000         1095.000000

# %%
### Datasets
# Description of data set available, at the field level (see table): 

data.head(10)
# Out:
#    Fiscal Year Released  Recidivism Reporting Year      Race - Ethnicity Sex  \
# 0                  2010                       2013  White - Non-Hispanic   M
# 1                  2010                       2013  White - Non-Hispanic   M
# 2                  2010                       2013  White - Non-Hispanic   M
# 3                  2010                       2013  White - Non-Hispanic   M
# 4                  2010                       2013  Black - Non-Hispanic   M
# 5                  2010                       2013  White - Non-Hispanic   M
# 6                  2010                       2013  White - Non-Hispanic   M
# 7                  2010                       2013  White - Non-Hispanic   M
# 8                  2010                       2013  White - Non-Hispanic   M
# 9                  2010                       2013  White - Non-Hispanic   M
#
#   Age At Release  Convicting Offense Classification Convicting Offense Type  \
# 0        Under 25                          D Felony                 Violent
# 1    55 and Older                          D Felony            Public Order
# 2           25-34                          D Felony                Property
# 3    55 and Older                          C Felony                    Drug
# 4           25-34                          D Felony                    Drug
# 5        Under 25                          D Felony                Property
# 6           45-54            Aggravated Misdemeanor            Public Order
# 7           45-54                          D Felony                Property
# 8           45-54            Aggravated Misdemeanor                 Violent
# 9           45-54                          C Felony                 Violent
#
#         Convicting Offense Subtype                  Release Type  \
# 0                          Assault                        Parole
# 1                              OWI                        Parole
# 2                         Burglary                        Parole
# 3                      Trafficking                        Parole
# 4                      Trafficking                        Parole
# 5                         Burglary  Discharged – End of Sentence
# 6  Sex Offender Registry/Residency                        Parole
# 7                         Burglary                        Parole
# 8                    Other Violent                        Parole
# 9                          Robbery                        Parole
#
#   Main Supervising District Recidivism - Return to Prison Recidivism Type  \
# 0                       4JD                           Yes            Tech
# 1                       7JD                           Yes            Tech
# 2                       5JD                           Yes            Tech
# 3                       8JD                           Yes            Tech
# 4                       3JD                           Yes            Tech
# 5                       NaN                           Yes            Tech
# 6                       3JD                           Yes             New
# 7                       1JD                           Yes            Tech
# 8                       5JD                           Yes            Tech
# 9                       8JD                           Yes            Tech
#
#    Days to Recidivism New Conviction Offense Classification  \
# 0                16.0                                   NaN
# 1                19.0                                   NaN
# 2                22.0                                   NaN
# 3                25.0                                   NaN
# 4                26.0                                   NaN
# 5                27.0                                   NaN
# 6                28.0                              D Felony
# 7                41.0                                   NaN
# 8                44.0                                   NaN
# 9                46.0                                   NaN
#
#   New Conviction Offense Type New Conviction Offense Sub Type  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
# 5                         NaN                             NaN
# 6                    Property                           Theft
# 7                         NaN                             NaN
# 8                         NaN                             NaN
# 9                         NaN                             NaN
#
#   Part of Target Population
# 0                       Yes
# 1                       Yes
# 2                       Yes
# 3                       Yes
# 4                       Yes
# 5                        No
# 6                       Yes
# 7                       Yes
# 8                       Yes
# 9                       Yes

# %%
data.corr()
# Out:
#                            Fiscal Year Released  Recidivism Reporting Year  \
# Fiscal Year Released                   1.000000                   1.000000
# Recidivism Reporting Year              1.000000                   1.000000
# Days to Recidivism                    -0.010371                  -0.010371
#
#                            Days to Recidivism
# Fiscal Year Released                -0.010371
# Recidivism Reporting Year           -0.010371
# Days to Recidivism                   1.000000

# %%
### Well-articulated problem statement with "specific aim" and hypothesis, based on your lightning talk

# Specific Aim: 
# Understand relationship between recidivism and race, gender, age, convicting offense classification, and release type.
## Hypothesis:
## Male, younger, non-white, more "serious" or grave offenses will likely have greater likelihood of recidivism and 
## likely will have shorter amount of time before returning to prison (days to recidivism)

## METHODS AND MODELS
## Logistic Regression for predicting the likelihood of an individual will go back to prison (training and test data)
## Linear regression for predicting when an individual who is sent back to prison gets sent back (training and test data)
## Random Forest Modelling for predicting which category an individual will fall inot (low risk - no recidivism in 3 years)
### mid-risk (committ a crime, but not serious one) or high risk (committ a serious crime incl. murder, attempted murder
## aggravated assault, rape, arson)
 

## Goals: 
#Be able to predict with >80% accuracy who is sent back to prison 
#Look at the factors that are most important in determining who gets sent back to prison

#Be able to predict with >70% when someone who is sent back gets sent back
#Understand which factors are most important in determining when someone gets sent back to prison
# Out:
#   File "<ipython-input-16-804e9fa1d859>", line 4
#     Understand relationship between
#                           ^
# SyntaxError: invalid syntax
